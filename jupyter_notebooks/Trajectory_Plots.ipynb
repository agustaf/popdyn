# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
trajectory_data = pd.read_csv('../population_trajectory.txt')

# %%
trajectory_data.head()
# Out:
#    timestep  prey  predators
# 0         0   100        100
# 1        10    98        101
# 2        20    97        102
# 3        30    97        102
# 4        40    97        101

# %%
axes = trajectory_data.plot(x='prey', y='predators', figsize=(10, 10), legend=False)
axes.set_ylabel('predators')
# Out:
# Text(0,0.5,'predators')

# %%
trajectory_data.plot(x='timestep', figsize=(15, 8))
